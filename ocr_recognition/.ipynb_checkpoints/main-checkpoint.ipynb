# %% [markdown]
# ## demo

# %%
#-*- coding:utf-8 -*-
import os
import time
import shutil
import numpy as np
from PIL import Image
from glob import glob
import matplotlib.pyplot as plt
from pylab import *

image_files = glob('./test_images/*.*')


if __name__ == '__main__':
    result_dir = './test_result'
    if os.path.exists(result_dir):
        shutil.rmtree(result_dir)
    os.mkdir(result_dir)
    plt.figure()
    i=1
    for image_file in sorted(image_files):
        image = np.array(Image.open(image_file).convert('RGB'))
        t = time.time()
#         result, image_framed = ocr.model(image)   #reslut： 文字结果
#                                                   #image_framed: 文本检测后的图片
        plt.subplot(2,2,i)
        plt.imshow(image)
        show()
        print("Mission complete, it took {:.3f}s".format(time.time() - t))
        print("\nRecognition Result:\n")
        for key in result:
            print(result[key][1])
# Out:
# Mission complete, it took 0.056s
#
# Recognition Result:
# Mission complete, it took 0.048s
#
# Recognition Result:
# Mission complete, it took 0.058s
#
# Recognition Result:
# Mission complete, it took 0.048s
#
# Recognition Result:
# Mission complete, it took 0.051s
#
# Recognition Result:
# Mission complete, it took 0.053s
#
# Recognition Result:
# Mission complete, it took 0.052s
#
# Recognition Result:
# Mission complete, it took 0.053s
#
# Recognition Result:
# Mission complete, it took 0.049s
#
# Recognition Result:
# Mission complete, it took 0.049s
#
# Recognition Result:
# Mission complete, it took 0.082s
#
# Recognition Result:
